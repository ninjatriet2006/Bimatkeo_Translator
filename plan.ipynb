# %%
# ==========================================================================
# BIMATKEO TRANSLATOR - TRẠNG THÁI TIẾN ĐỘ & METADATA DỰ ÁN
# ==========================================================================
# GHI CHÚ: Các tác nhân AI tương lai có thể tự động phân tích và cập nhật ô này
#          để phản ánh các thay đổi tiến độ theo chương trình.

PROJECT_STATUS = {
    "project_name": "Bimatkeo Translator (Modular)",
    "current_phase": "Đa nhánh (Multi-branching)",
    "completed_phases": [1, 2, 3],
    "in_progress_phases": [4],
    "completion_percentage": 75,
    "last_updated": "2026-06-23",
    "phases": {
        "Phase 1: UI & Config Modularity": "Hoàn thành",
        "Phase 1.5: Core Code Optimization (AI Agent Skills)": "Hoàn thành",
        "Phase 2: Decoupled Process Isolation": "Hoàn thành",
        "Phase 3: Translator Engine (Offline & API)": "Hoàn thành",
        "Phase 4: Text Detection & OCR Integration": "Đã hoàn thành",
        "Phase 5: Speech Bubble Inpainting Integration": "Lên kế hoạch",
        "Phase 5B: Manga Colorization": "Lên kế hoạch",
        "Phase 6: Typesetting & Rendering Integration": "Lên kế hoạch",
        "Phase 7: Parallel Pipelined Queue & Performance Tuning": "Hoàn thành một phần (Kiến trúc Lõi)",
        "Phase 8: Human-in-the-Loop & Interactive Editor": "Lên kế hoạch"
    }
}

print(f"--- {PROJECT_STATUS['project_name']} ---")
current_phase_key = PROJECT_STATUS['current_phase']
status_desc = PROJECT_STATUS['phases'].get(current_phase_key, "Tiến hành song song các nhánh")
print(f"Trạng thái hiện tại: {current_phase_key} - {status_desc}")
print(f"Tiến độ tổng thể: {PROJECT_STATUS['completion_percentage']}% (Cập nhật lần cuối: {PROJECT_STATUS['last_updated']})")
# Out:
# --- Bimatkeo Translator (Modular) ---
# Trạng thái hiện tại: Đa nhánh (Multi-branching) - Tiến hành song song các nhánh
# Tiến độ tổng thể: 75% (Cập nhật lần cuối: 2026-06-23)

# %% [markdown]
# # 🎌 Bimatkeo Translator - Trình theo dõi tiến độ & Lộ trình (Modular)
#
# Chào mừng bạn đến với notebook trực quan hóa tiến độ cho dự án **Bimatkeo Translator**. Dự án này được xây dựng dựa trên triết lý cốt lõi là **cô lập thành phần nghiêm ngặt và tính mô-đun hóa** nhằm đảm bảo khả năng bảo trì, sự ổn định đa nền tảng và độ phản hồi nhanh của giao diện.
#
# ---
#
# ## 🏗️ 1. Kiến trúc Triển khai Thực chiến (High-Level System Architecture)
#
# Để đảm bảo độ phản hồi tối đa của giao diện và tránh nghẽn I/O đĩa vật lý, hệ thống liên kết các khối chức năng theo sơ đồ tổng quan sau. Luồng dữ liệu ảnh và text được luân chuyển trực tiếp trong RAM:
#
# ### 📊 Sơ đồ liên kết các Khối chức năng (High-Level System Diagram)
#
# ```mermaid
# graph LR
#     Block1["1. UI và Giao tiếp - IPC<br>(PySide6 GUI)"] -->|"Ghi JSON và khởi chạy CLI"| Block2["2. Core Pipeline Engine<br>(Luồng Subprocess chính)"]
#     Block2 -->|"Yêu cầu suy luận và nạp model"| Block3["3. Hệ thống Plugin (Factory/ABC)<br>(Các mô hình ML độc lập)"]
#     Block3 -.->|"Dependency Injection"| Block4["4. Worker Nodes (In-Memory)<br>(Luồng xử lý đa luồng gối đầu)"]
#     Block2 ==>|"Khởi tạo luồng và Queue RAM"| Block4
#     Block2 -.->|"Gửi stdout log PROG"| Block1
# ```

# %% [markdown]
# ## 🗺️ 2. Lộ trình Dự án & Dòng thời gian Tiến độ
#
# Dưới đây là trình tự tiến độ phát triển dự án. Phase hiện tại đang được thực hiện là **Phase 4**.
#
# ```mermaid
# graph LR
#   %% Khởi tạo Gốc
#   Root((BIMATKEO<br/>TRANSLATOR))
#
#   %% 1. Kiến trúc Lõi
#   %% 1.5 AI Skills
#   Root --> Skill(Thiết lập AI Agent Skills):::done
#   Skill --> skill1[Modern Python & Pytest]:::done
#   Skill --> skill2[Bảo mật & Decoupling]:::done
#
#   Root --> Core(Kiến trúc Lõi):::done
#   Core --> UI(UI & Config):::done
#   UI --> ui1[Dynamic Theming]:::done
#   UI --> ui2[YAML Auto-Repair]:::done
#
#   Core --> Iso(Process Isolation):::done
#   Iso --> iso1[Subprocess Decoupling]:::done
#   Iso --> iso2[OOM Safe Fallback]:::done
#
#   Core --> Pipe(Parallel Pipeline):::wip
#   Pipe --> pipe1[Fork-Join Queue RAM]:::done
#   Pipe --> pipe2[Zero-Copy DTO]:::wip
#
#   %% 2. Dịch thuật
#   Root --> Trans(Động cơ Dịch):::done
#   Trans --> Off(Mô hình Offline):::done
#   Off --> off1[NLLB, MBart50, M2M100]:::done
#   Off --> off2[Tự động nạp VRAM]:::done
#
#   Trans --> Api(API & Cloud):::done
#   Api --> api1[OpenAI, Gemini, NLLB API]:::done
#   Api --> api2[Translator Chain]:::done
#
#   Trans --> Safe(An toàn dữ liệu):::done
#   Safe --> safe1[JSON Strict Schema]:::done
#   Safe --> safe2[Unified Context Profiles]:::done
#
#   %% 3. Đồ họa Vision
#   Root --> Vis(Xử lý Đồ họa):::planned
#   Vis --> Ocr(Text Detection & OCR):::done
#   Ocr --> ocr1[CRAFT, CTD, MangaOCR]:::done
#
#   Vis --> Inp(Xóa Nền Inpaint):::planned
#   Inp --> inp1[LaMa, PatchMatch]:::planned
#   Inp --> inp2[Text Mask Generation]:::planned
#
#   Vis --> Col(Tô Màu Manga):::planned
#   Col --> col1[Auto Colorization]:::planned
#   Col --> col2[ESRGAN Upscale]:::planned
#
#   Vis --> Ren(Dàn Trang Render):::planned
#   Ren --> ren1[BBox Word Wrapping]:::planned
#   Ren --> ren2[Layered PSD Export]:::planned
#
#   %% 4. Tương tác
#   Root --> Int(Tương tác MTPE):::planned
#   Int --> hil(Human-in-the-loop):::planned
#   hil --> hil1[Sửa bản dịch Live]:::planned
#
#   Int --> exp(Export Scripts):::planned
#   exp --> exp1[Đồng bộ Text/File]:::planned
#
#   %% Định nghĩa màu sắc (Hoạt động hoàn hảo trên Graph)
#   classDef done fill:#047857,stroke:#10b981,stroke-width:2px,color:#fff
#   classDef wip fill:#b45309,stroke:#f59e0b,stroke-width:2px,color:#fff
#   classDef planned fill:#1e293b,stroke:#475569,stroke-width:1px,color:#94a3b8
# ```
#
# ### 📝 Phân loại Kiến trúc & Lộ trình (Modular & Decoupled Framework)
#
# Để đảm bảo nguyên tắc SOLID và tính cắm-là-chạy (Plug-and-Play), tránh việc thêm/sửa/xóa một tính năng làm sập toàn bộ hệ thống, 44+ tính năng cốt lõi được phân loại nghiêm ngặt vào các Phase độc lập. Mỗi Phase giao tiếp với nhau qua cấu trúc In-Memory Queue và các Abstract Base Class.
#
# | Phase | Thành phần cốt lõi & Tính năng phân mảnh (Modular Features) | Kiến trúc Bất đồng bộ (Async/Decoupled) | Trạng thái |
# | :--- | :--- | :--- | :--- |
# | **Phase 1: UI & Config**<br>*(Giao diện & Cấu hình)* | **Tính năng UI:**<br>• Dynamic Theming System (Thay đổi giao diện không cần khởi động lại).<br>• Multilingual UI (Đa ngôn ngữ GUI).<br>• API WebSocket Listener (Mode WS phục vụ Extension/Mobile App).<br>**Tính năng Config:**<br>• Per-Job Configuration (Cấu hình riêng cho từng folder).<br>• Auto-Repair Config (Tự phục hồi file YAML/JSON hỏng).<br>• File System Operations (Sao lưu, chống ghi đè). | • Worker chạy nền cho: Kiểm tra cập nhật, tải danh sách Font hệ thống.<br>• Non-blocking UI. | 🟢 **Hoàn thành 100%** |
# | **Phase 1.5: Core Code Optimization**<br>*(Chuẩn hóa Mã Nguồn)* | **Bộ kỹ năng AI Agent:**<br>• `modern-python` (Cú pháp Python 3.10+, Type Hinting gắt gao).<br>• `pytest-skill` (Testability, loại bỏ phụ thuộc cứng).<br>• `security-best-practices` (Quản lý SSL, tránh rò rỉ Key).<br>• `ask-questions` (Chặn ảo giác, yêu cầu làm rõ trước khi code). | • Áp dụng `match/case` loại bỏ if/else dài.<br>• Refactor toàn bộ utils. | 🟢 **Hoàn thành 100%** |
# | **Phase 2: Process Isolation**<br>*(Cô lập tiến trình & Tối ưu)* | **Tính năng Pipeline:**<br>• Modular Bypassing (Cấu hình tắt/bật độc lập bất kỳ mô-đun nào: OCR, Dịch, Xóa nền, Render).<br>• Standalone Tasks (Chỉ dịch, Chỉ lên màu, Chỉ xóa nền).<br>• Archive Processing (Tự động giải nén & đóng gói CBZ/ZIP/PDF).<br>• No-Text Skipping (Bypass ảnh chỉ có tranh hành động).<br>**Tối ưu Tài nguyên:**<br>• OOM Safe Fallback (Tự động dọn rác VRAM `empty_cache()`, giảm batch).<br>• GPU Limited Mode (Offload model nặng sang CPU cho máy yếu). | • `os.setsid` cô lập Process Group.<br>• Đọc Log Stdout bất đồng bộ `[PROG][STAGE]`.<br>• Pydantic Schema Validation từ xa. | 🟢 **Hoàn thành 100%** |
# | **Phase 3: Translator Engine**<br>*(Dịch thuật & AI Text)* | **Abstract Base Class:** `BaseTranslator`<br>**Tính năng Dịch:**<br>• Offline Translation (Sugoi/CT2, NLLB, MBart - Chạy Local 100%).<br>• API & Cloud AI (OpenAI, Gemini, Groq...).<br>• Translator Chain (Dịch nối tiếp Fallback nhiều model).<br>• Contextual Batching (Truyền ngữ cảnh trang trước cho LLM).<br>**Kiểm soát Chất lượng & An toàn AI:**<br>• JSON Maximum Safety Schema (Ép AI xuất JSON chuẩn hóa chống Crash).<br>• Unified Context Profiles (Gom Từ điển Pre/Post và Prompt vào 1 file duy nhất).<br>• Post-Translation Validation & Hallucination Detection (Tự động Retry nếu ảo giác/lặp từ). | • Tải weights và chạy suy luận AI trên luồng độc lập, không block UI. | 🟢 **Hoàn thành 100%** |
# | **Phase 4: Text Detection & OCR** | Nhận diện khung truyện, load OCR... | 🟢 **Đã hoàn thành** |
# | **Phase 5: Inpainting**<br>*(Xóa nền bóng thoại)* | **Abstract Base Class:** `BaseInpainter`<br>**Tính năng Xóa nền:**<br>• Booru Tagging-Guided Inpainting (Trích xuất Tag làm Prompt cho Stable Diffusion).<br>• Text Mask Generation (Binarization/CRAFT mask).<br>• Dense CRF Mask Processing (Tinh chỉnh Mask cấp độ nét chữ).<br>• Inpainting Precision Tuning (fp32, fp16, bf16 tiết kiệm VRAM). | • Xử lý mảng Tensor đồ họa nặng trên luồng nền. | ⚪ *Đang lên kế hoạch* |
# | **Phase 5B: Colorization**<br>*(Tô màu & Nâng cấp ảnh)* | **Tính năng Đồ họa:**<br>• Auto Manga Colorization (Tô màu tự động).<br>• Super Resolution Upscaling (ESRGAN/Waifu2x làm nét ảnh).<br>• Smart Auto-Scaling (Downscale trả về kích thước gốc chống phình dung lượng). | • Queue xử lý song song tùy chọn. | ⚪ *Đang lên kế hoạch* |
# | **Phase 6: Typesetting**<br>*(Vẽ chữ & Layout)* | **Abstract Base Class:** `BaseRenderer`<br>**Tính năng Layout:**<br>• Auto-Fit, Polygon Word Wrapping (Bẻ dòng theo đa giác Oval).<br>• Dynamic BBox Auto-Scaling (Tự co giãn khung thoại nếu chữ quá dài).<br>• Bi-directional Arabic Text Rendering (Hiển thị text đảo chiều RTL).<br>**Tính năng Đồ họa Chữ:**<br>• Dynamic Font Coloring (Tự động trích xuất màu Foreground/Background gốc).<br>• Font Size Offset/Minimum (Khống chế size chữ nhỏ nhất).<br>• Typography Engine & Google Fonts Cloud (Sideload font, căn lề).<br>• Font Caching (Cache font vào VRAM).<br>**Tính năng Xuất File:**<br>• Layered Export PSD/XCF (Chữ là Editable Text Layer).<br>• Multi-format Export (PNG/WEBP/JPG). | • Kết xuất ma trận điểm ảnh đè lên ảnh sạch qua OpenCV/Pillow bất đồng bộ. | ⚪ *Đang lên kế hoạch* |
# | **Phase 7: Parallel Pipeline**<br>*(Tối ưu Đa luồng)* | **Kiến trúc Luồng:**<br>• Fork-Join Parallel Pipeline (Truyền DTO qua Queue RAM, Zero-Copy).<br>• Batch Concurrent Mode (Chia nhỏ Batch LLM dịch song song).<br>• Asynchronous Priority Lock & Throttling (Quản lý hàng đợi API/GPU chống nghẽn).<br>• On-Demand Downloader (ModelWrapper tải lười, check SHA256, tự động cấp quyền). | • Truyền dữ liệu trực tiếp In-Memory không ghi file tạm ổ cứng. | 🟡 **Đang thực hiện (Hoàn thành kiến trúc)** |
# | **Phase 8: Human-in-the-Loop**<br>*(Chỉnh sửa thủ công)* | **Tính năng Tương tác:**<br>• Machine Translation Post Editing - MTPE (Giao diện sửa bản dịch trước khi in).<br>• Export/Import Text Script (Xuất/Nhập file txt để dịch tay ngoài).<br>• Auto Bubble Color Detection (Tự bỏ qua chữ nằm trên vùng màu không phải hộp thoại). | • Khóa luồng Render, chờ sự kiện (Event) Approve từ người dùng. | ⚪ *Đang lên kế hoạch* |

# %% [markdown]
# ---
#
# ## ⚙️ 3. Giải phẫu kiến trúc phần mềm lõi (Core Code Logic Design)
#
# Để đảm bảo tính linh hoạt, cắm-là-chạy và không gây nghẽn phần cứng, hệ thống được lập trình dựa trên 4 mô-đun lõi được trực quan hóa chi tiết dưới đây:
#
# ### 1️⃣ Khối 1: UI và Giao tiếp liên tiến trình (IPC) - Phase 1 & 2
# UI Client (PySide6) gửi yêu cầu dịch thuật sang Backend bằng cách validate tham số qua Pydantic Schema, khởi tạo và trao đổi cấu hình (Dictionary) thông qua `multiprocessing.Process` và `Queue` trên RAM. Tiến trình UI sử dụng một vòng lặp `while` an toàn không chặn để lắng nghe log được gửi về từ Backend qua Shared Queue.
#
# ```mermaid
# graph TD
#     ui_client["UI Client - PySide6 GUI"]
#     pydantic_schema["Pydantic Schema - model_name, src_lang, tgt_lang, batch_size"]
#     sub_popen["subprocess.Popen - app/core/pipeline.py"]
#     stdout_reader["Trình đọc stdout không chặn - Daemon Thread"]
#
#     ui_client -->|"1. Validate Data - Xác thực dữ liệu"| pydantic_schema
#     pydantic_schema -->|"2. Spawn multiprocessing.Process"| process_worker
#     sub_popen -.->|"Log tiến trình: PROG - STAGE - Tiến trình"| stdout_reader
#     stdout_reader -.->|"Cập nhật UI"| ui_client
# ```
#
# #### 📋 Chi tiết triển khai & Giao tiếp:
# - **Cấu hình & Tùy biến (Configuration)**: UI quản lý cấu hình người dùng thông qua các tệp cấu hình YAML đặt tại `.config/configs/`. Khi người dùng thay đổi tùy chọn trên giao diện, các tham số này sẽ được kiểm tra hợp lệ bằng schema Pydantic (`class PipelineArgs(BaseModel)`) trước khi gửi sang backend nhằm loại bỏ lỗi sai kiểu dữ liệu ngay từ đầu.
# - **Cách Gọi (Call)**: Giao diện GUI tạo một từ điển cấu hình `dict` và khởi chạy một tiến trình con (`multiprocessing.Process`) cùng với hai hàng đợi `log_queue` và `result_queue` trên RAM:
# ```python
# # Minh họa cơ chế GUI gọi CLI Backend độc lập
# import subprocess
# import os
# import json
# import time
#
# task_data = {
#     "profile": "nllb_manga",
#     "src_lang": "ja",
#     "tgt_lang": "vi",
#     "batch_size": 4,
#     "images": ["/absolute/path/to/page1.png", "/absolute/path/to/page2.png"]
# }
#
# task_file = f"temp/task_{int(time.time())}.json"
# os.makedirs("temp", exist_ok=True)
# with open(task_file, "w", encoding="utf-8") as f:
#     json.dump(task_data, f, ensure_ascii=False, indent=4)
#
# # Khởi chạy CLI chạy nền, cô lập nhóm tiến trình con
# process = subprocess.Popen(
#     ["python", "app/core/pipeline.py", "--task", task_file],
#     stdout=subprocess.PIPE,
#     stderr=subprocess.PIPE,
#     text=True,
#     preexec_fn=os.setsid  # Chỉ chạy trên Linux: Tách nhóm tiến trình để tránh dính zombie process
# )
# ```
# - **Cách Nhận kết quả (Receive)**: Tiến trình UI không chặn (non-blocking) các sự kiện bằng cách khởi chạy một luồng Daemon Thread để liên tục đọc đầu ra chuẩn stdout từ tiến trình con. Khi phát hiện các nhãn tiến độ định dạng `[PROG]`, luồng này sẽ cập nhật giao diện thông qua cơ chế Signal/Slot của Qt:
# ```python
# # Luồng nền giám sát stdout và cập nhật tiến độ lên UI
# import threading
#
# def monitor_stdout(process, signal_emitter):
#     for line in iter(process.stdout.readline, ""):
#         line = line.strip()
#         if line.startswith("[PROG]"):
#             # Ví dụ: "[PROG][OCR] [##--------] 20% - Đang quét chữ trang 1"
#             parts = line.split("]", 2)
#             stage = parts[1].replace("[", "")
#             progress_desc = parts[2].strip()
#             # Phát tín hiệu an toàn về Main GUI Thread
#             signal_emitter.emit(stage, progress_desc)
#     process.wait()
# ```
#
# ---
#
# ### 2️⃣ Khối 2: Core Pipeline Engine (Luồng phụ Subprocess) - Phase 2
# Luồng chính của subprocess phân tích các tham số truyền sang (`Parse Args`), khởi tạo trạng thái dịch thuật và tự động tính toán batching để phân chia lô ảnh trong RAM. Sau đó, nó đẩy ảnh vào hàng đợi ảnh gốc đầu tiên (`q_in`) nằm trên bộ nhớ RAM.
#
# ```mermaid
# graph TD
#     sub_popen["Nhận tín hiệu từ Subprocess Popen"]
#     init_state["Khởi tạo Trạng thái và Tính toán Batching"]
#     q_in["Hàng đợi Ảnh gốc - RAM"]
#
#     sub_popen ==>|"3. Parse Args - Phân tích tham số"| init_state
#     init_state ==>|"4. Đẩy ảnh vào hàng đợi"| q_in
# ```
#
# #### 📋 Chi tiết triển khai & Giao tiếp:
# - **Cách Nhận (Receive)**: Tiến trình con nhận trực tiếp Dictionary từ `args` và chạy lõi Pipeline. Bất kỳ Log hay Error nào đều được đẩy ngược về `log_queue`:
# ```python
# import argparse
# import json
#
# parser = argparse.ArgumentParser()
# parser.add_argument("--task", type=str, required=True, help="Đường dẫn tệp cấu hình JSON tạm thời")
# args = parser.parse_args()
#
# with open(args.task, "r", encoding="utf-8") as f:
#     task_config = json.load(f)
# ```
# - **Cách Khởi tạo & Điều phối (Call/Implementation)**: Engine sẽ khởi tạo 5 hàng đợi đa luồng (`queue.Queue`) trên RAM đóng vai trò là các trạm chuyển tiếp dữ liệu ảnh và văn bản. Tiếp theo, nó đọc ảnh từ đĩa vào RAM dưới dạng đối tượng `PageContext` DTO và đẩy vào `q_in` để các Worker Thread bắt đầu làm việc gối đầu:
# ```python
# import queue
# import cv2
#
# # Khởi tạo hàng đợi trung gian trên bộ nhớ RAM
# q_in = queue.Queue(maxsize=10)
# q_ocr = queue.Queue(maxsize=10)
# q_trans = queue.Queue(maxsize=10)
# q_inpaint = queue.Queue(maxsize=10)
# q_render = queue.Queue(maxsize=10)
#
# # Đọc ảnh và chuyển đổi thành cấu trúc DTO PageContext
# for img_path in task_config["images"]:
#     img_data = cv2.imread(img_path)  # Ảnh được nạp trực tiếp lên RAM dưới dạng mảng numpy
#     ctx = PageContext(page_id=os.path.basename(img_path), original_image=img_data)
#     q_in.put(ctx)
# ```
#
# ---
#
# ### 3️⃣ Khối 3: Hệ thống Plugin (Factory Pattern & ABC) - Phase 3, 4, 5, 6
# Để đảm bảo tính cắm-là-chạy, ứng dụng định nghĩa các giao diện trừu tượng bằng `Abstract Base Class` (ABC). Mỗi mô-đun ML độc lập kế thừa lớp interface và được nạp động thông qua một Factory Registry tương ứng. Điều này cho phép mở rộng hoặc thay thế bất kỳ model nào mà không chạm vào pipeline chính.
#
# #### 🅰️ Sơ đồ Mô-đun OCR Độc lập (Modular OCR)
# ```mermaid
# graph TD
#     abc_det[["BaseTextDetector ABC - load_model, detect"]]
#     abc_rec[["BaseTextRecognizer ABC - load_model, recognize"]]
#     ctd_det["CTD_Impl (Detector)"]
#     manga_rec["MangaOCR_Impl (Recognizer)"]
#     ocr_factory["Detector & Recognizer Factory"]
#     w_ocr["Worker OCR"]
#
#     ctd_det -.->|"Kế thừa"| abc_det
#     manga_rec -.->|"Kế thừa"| abc_rec
#     ocr_factory -->|"Khởi tạo động"| abc_det
#     ocr_factory -->|"Khởi tạo động"| abc_rec
#     w_ocr -->|"1. Gọi Detect"| abc_det
#     w_ocr -->|"2. Gọi Recognize"| abc_rec
# ```
#
# #### 🅱️ Sơ đồ Mô-đun Dịch thuật Độc lập (Modular Translator)
# ```mermaid
# graph TD
#     abc_trans[["BaseTranslator ABC - load_weights, translate"]]
#     nllb_trans["NLLB200_Impl"]
#     mbart_trans["MBart50_Impl"]
#     trans_factory["Translator Factory Registry"]
#     w_trans["Worker Dịch thuật"]
#
#     nllb_trans -.->|"Kế thừa và Triển khai"| abc_trans
#     mbart_trans -.->|"Kế thừa và Triển khai"| abc_trans
#     trans_factory -->|"Khởi tạo động"| abc_trans
#     w_trans -->|"Gọi Interface BaseTranslator"| abc_trans
# ```
#
# #### 🅲 Sơ đồ Mô-đun Xóa nền Độc lập (Modular Inpainter)
# ```mermaid
# graph TD
#     abc_inpaint[["BaseInpainter ABC - load_model, inpaint"]]
#     lama_inpaint["LamaInpainter_Impl"]
#     patch_inpaint["PatchMatch_Impl"]
#     inpaint_factory["Inpainter Factory Registry"]
#     w_inpaint["Worker Inpainting"]
#
#     lama_inpaint -.->|"Kế thừa và Triển khai"| abc_inpaint
#     patch_inpaint -.->|"Kế thừa và Triển khai"| abc_inpaint
#     inpaint_factory -->|"Khởi tạo động"| abc_inpaint
#     w_inpaint -->|"Gọi Interface BaseInpainter"| abc_inpaint
# ```
#
# #### 🅲3 Sơ đồ Mô-đun Phóng đại Độc lập (Modular Upscaler - Tiền xử lý Phase 4)
# ```mermaid
# graph TD
#     abc_upscale[["BaseUpscaler ABC - load_model, upscale"]]
#     esrgan_upscale["ESRGAN_Impl"]
#     upscale_factory["Upscaler Factory Registry"]
#     w_upscale["Worker Upscaler"]
#
#     esrgan_upscale -.->|"Kế thừa và Triển khai"| abc_upscale
#     upscale_factory -->|"Khởi tạo động"| abc_upscale
#     w_upscale -->|"Gọi Interface BaseUpscaler"| abc_upscale
# ```
#
# #### 🅲2 Sơ đồ Mô-đun Lên màu Độc lập (Modular Colorizer - Phase 5B)
# ```mermaid
# graph TD
#     abc_color[["BaseColorizer ABC - load_model, colorize"]]
#     manga_color["MangaColorizer_Impl"]
#     color_factory["Colorizer Factory Registry"]
#     w_color["Worker Colorizer"]
#
#     manga_color -.->|"Kế thừa và Triển khai"| abc_color
#     color_factory -->|"Khởi tạo động"| abc_color
#     w_color -->|"Gọi Interface BaseColorizer"| abc_color
# ```
#
# #### 🅳 Sơ đồ Mô-đun Vẽ chữ Độc lập (Modular Renderer)
# ```mermaid
# graph TD
#     abc_render[["BaseRenderer ABC - load_fonts, render"]]
#     pillow_render["PillowRenderer_Impl"]
#     opencv_render["OpenCVRenderer_Impl"]
#     render_factory["Renderer Factory Registry"]
#     w_render["Worker Render"]
#
#     pillow_render -.->|"Kế thừa và Triển khai"| abc_render
#     opencv_render -.->|"Kế thừa và Triển khai"| abc_render
#     render_factory -->|"Khởi tạo động"| abc_render
#     w_render -->|"Gọi Interface BaseRenderer"| abc_render
# ```
#
# #### 📋 Đặc tả Lớp giao tiếp trừu tượng (Abstract Base Classes - ABC):
# ```python
# from abc import ABC, abstractmethod
# import numpy as np
#
# class BaseTextDetector(ABC):
#     @abstractmethod
#     def load_model(self, model_path: str) -> None:
#         """Tải mô hình phát hiện khung chữ (như comic-text-detector, YOLO)."""
#         pass
#
#     @abstractmethod
#     def detect(self, image: np.ndarray) -> list[list[int]]:
#         """Quét tìm và trả về danh sách tọa độ bboxes [x_min, y_min, x_max, y_max]."""
#         pass
#
# class BaseTextRecognizer(ABC):
#     @abstractmethod
#     def load_model(self, model_path: str) -> None:
#         """Tải mô hình nhận diện chữ (như MangaOCR, PaddleOCR)."""
#         pass
#
#     @abstractmethod
#     def recognize(self, image_crop: np.ndarray) -> str:
#         """Nhận ảnh đã cắt gọt chứa 1 dòng chữ và trả về văn bản text."""
#         pass
#
# class BaseUpscaler(ABC):
#     @abstractmethod
#     def load_model(self, model_path: str) -> None:
#         """Tải mô hình phóng đại ảnh (như Real-ESRGAN)."""
#         pass
#
#     @abstractmethod
#     def upscale(self, image: np.ndarray, ratio: int) -> np.ndarray:
#         """Nhận ảnh gốc và phóng to theo tỷ lệ (2x, 3x, 4x) để tăng độ nét."""
#         pass
#
# class BaseColorizer(ABC):
#     @abstractmethod
#     def load_model(self, model_path: str) -> None:
#         """Tải mô hình tô màu Manga (như MangaColorization)."""
#         pass
#
#     @abstractmethod
#     def colorize(self, image: np.ndarray) -> np.ndarray:
#         """Nhận ảnh truyện trắng đen và trả về ảnh đã được tô màu."""
#         pass
#
# class BaseTranslator(ABC):
#     @abstractmethod
#     def load_weights(self, model_path: str) -> None:
#         """Tải trọng số mô hình dịch thuật (NLLB, M2M100...) từ đường dẫn được chỉ định."""
#         pass
#
#     @abstractmethod
#     def translate(self, texts: list[str], src_lang: str, tgt_lang: str) -> list[str]:
#         """Dịch danh sách các đoạn text tiếng nguồn sang tiếng đích."""
#         pass
#
# class BaseInpainter(ABC):
#     @abstractmethod
#     def load_model(self, model_path: str) -> None:
#         """Tải mô hình inpainting (Lama, PatchMatch...) lên bộ nhớ."""
#         pass
#
#     @abstractmethod
#     def inpaint(self, image: np.ndarray, bboxes: list[list[int]]) -> np.ndarray:
#         """Nhận ảnh gốc và tọa độ bboxes chứa văn bản, thực hiện xóa chữ và trả về mảng ảnh nền sạch."""
#         pass
#
# class BaseRenderer(ABC):
#     @abstractmethod
#     def load_fonts(self, font_path: str) -> None:
#         """Cấu hình và nạp font chữ TrueType/OpenType hỗ trợ viết chữ."""
#         pass
#
#     @abstractmethod
#     def render(self, image: np.ndarray, bboxes: list[list[int]], texts: list[str]) -> np.ndarray:
#         """Vẽ văn bản tiếng đích (texts) lên ảnh nền đã làm sạch (image) tại đúng vị trí bboxes."""
#         pass
# ```
#
# #### 📋 Cơ chế nạp động Factory Registry:
# ```python
# # Triển khai Factory tự động đăng ký dynamic subclass thông qua decorator
# class TranslatorFactory:
#     _registry = {}
#
#     @classmethod
#     def register(cls, name: str):
#         """Decorator dùng để đăng ký một triển khai dịch thuật cụ thể."""
#         def decorator(subclass):
#             cls._registry[name] = subclass
#             return subclass
#         return decorator
#
#     @classmethod
#     def create(cls, name: str, model_path: str) -> BaseTranslator:
#         """Tạo và trả về instance của lớp triển khai dịch thuật."""
#         if name not in cls._registry:
#             raise ValueError(f"Mô hình dịch '{name}' chưa được đăng ký vào Factory.")
#         impl_class = cls._registry[name]
#         instance = impl_class()
#         instance.load_weights(model_path)
#         return instance
#
# # Ví dụ đăng ký NLLB-200
# @TranslatorFactory.register("nllb-200")
# class NLLBTranslator(BaseTranslator):
#     def load_weights(self, model_path: str):
#         # Code tải weights dùng HuggingFace hoặc CTranslate2
#         pass
#
#     def translate(self, texts: list[str], src_lang: str, tgt_lang: str) -> list[str]:
#         # Logic thực thi dịch thuật offline
#         return [f"[Dịch NLLB] {t}" for t in texts]
# ```
#
# ---
#
# ### 4️⃣ Khối 4: Worker Nodes (Xử lý gối đầu In-Memory) - Phase 7
# Để loại bỏ ghi file tạm làm mòn SSD, ảnh và text được luân chuyển trực tiếp trên RAM dưới dạng đối tượng `PageContext` DTO thông qua các Hàng đợi bất đồng bộ (`queue.Queue`). Sử dụng **thư viện đa luồng gốc của Python** giúp truyền tham chiếu mảng NumPy trực tiếp giữa các Worker với chi phí sao chép bằng 0 (Zero Copy).
#
# #### 🧬 Sơ đồ xử lý gối đầu chia nhánh (Fork-Join Parallel Pipeline) (Parallel Workers Diagram)
# ```mermaid
# graph TD
#     q_in["Hàng đợi Ảnh gốc (RAM)"] ==> pre_process["Tiền xử lý (Upscale/Denoise/Auto-Rotate/Invert)"]
#     pre_process ==> w_ocr["1. Worker OCR"]
#
#     w_ocr ==>|"Sắp xếp Bbox & Lọc Regex (pre_dict)"| q_ocr_filtered["Hàng đợi OCR đã lọc"]
#
#     q_ocr_filtered ==>|"Sinh Text Mask từ Bbox"| q_inpaint["Hàng đợi Mask & Inpaint (RAM)"]
#     q_ocr_filtered ==>|"Gom câu (Contextual)"| q_trans["Hàng đợi Dịch thuật (RAM)"]
#
#     q_inpaint ==> w_inpaint["2A. Worker Inpainting (Xóa nền)"]
#     q_trans ==> w_trans["2B. Worker Dịch thuật (Offline/Online API + Chain)"]
#
#     w_inpaint ==> q_colorize["Hàng đợi Lên màu (Tùy chọn)"]
#     w_trans ==> q_render_sync["Hàng đợi Đồng bộ (Chờ 2A và 2B)"]
#
#     q_colorize ==> w_colorize["2C. Worker Colorizer (Tô màu truyện)"]
#     w_colorize ==> q_render_sync
#
#     q_render_sync ==>|"Nội suy đa giác bóng thoại"| w_render["3. Worker Render (Vẽ chữ phẳng)"]
#     q_render_sync ==>|"Phân lớp Layer"| w_export_psd["3B. Worker Xuất PSD/XCF (Editable Text)"]
#     w_render ==> w_export_img["3C. Worker Lưu Ảnh Phẳng (PNG/JPG/WEBP)"]
#     w_render ==> w_repack["Worker Nén Lưu trữ (CBZ/PDF/ZIP)"]
#     w_export_psd ==> w_repack
#     w_export_img ==> file_save["Ghi File Đích"]
#     w_repack ==> file_save
#
#     w_inpaint -->|"Giải phóng VRAM"| vram_cleanup["Dọn dẹp VRAM rác"]
# ```
#
# #### 🧬 Định nghĩa cấu trúc PageContext DTO trên RAM
# ```python
# from dataclasses import dataclass
# import numpy as np
#
# @dataclass
# class PageContext:
#     page_id: str                 # Định danh trang (Ví dụ: Chap_1.1_001)
#     original_image: np.ndarray   # Mảng ảnh gốc dạng NumPy lưu trên RAM
#     bboxes: list = None          # Tọa độ khung chữ (từ Worker OCR)
#     original_texts: list = None  # Văn bản gốc nhận diện được (từ Worker OCR)
#     translated_texts: list = None# Văn bản đã dịch (từ Worker Translator)
#     text_styles: list = None     # Định dạng chữ (Màu sắc, kích cỡ, font từ OCR phân tích)
#     inpainted_image: np.ndarray = None # Mảng ảnh đã xóa nền bong bóng thoại
#     rendered_image: np.ndarray = None  # Ảnh phẳng cuối cùng đã vẽ chữ (để xuất PNG/JPG)
# ```
#
# #### 📋 Triển khai luồng Worker chạy song song gối đầu (Pipeline Threads):
# Mỗi luồng Worker chịu trách nhiệm gọi một dịch vụ AI, thực hiện suy luận, cập nhật trường dữ liệu tương ứng trong DTO `PageContext` trên RAM và đẩy sang Queue tiếp theo mà không lưu bất kỳ file ảnh trung gian nào:
# ```python
# import threading
# import queue
#
# class OCRWorker(threading.Thread):
#     def __init__(self, in_q: queue.Queue, out_q: queue.Queue, detector: BaseTextDetector, recognizer: BaseTextRecognizer):
#         super().__init__()
#         self.in_q = in_q
#         self.out_q = out_q
#         self.detector = detector
#         self.recognizer = recognizer
#         self.daemon = True
#
#     def run(self):
#         while True:
#             ctx: PageContext = self.in_q.get()
#             if ctx is None:
#                 self.out_q.put(None)
#                 break
#
#             # 1. Gọi Detection để tìm khung chữ
#             bboxes = self.detector.detect(ctx.original_image)
#             ctx.bboxes = bboxes
#
#             # 2. Cắt ảnh và gọi Recognition cho từng khung
#             texts = []
#             for box in bboxes:
#                 crop = ctx.original_image[box[1]:box[3], box[0]:box[2]]
#                 # Kiểm tra crop hợp lệ
#                 if crop.size > 0:
#                     text = self.recognizer.recognize(crop)
#                     texts.append(text)
#                 else:
#                     texts.append("")
#
#             ctx.original_texts = texts
#
#             self.out_q.put(ctx)
#             self.in_q.task_done()
# ```
#
# ### 5️⃣ Quản lý Tài nguyên (Logic Chia lô & Giải phóng VRAM)
# Để tránh lỗi tràn bộ nhớ đồ họa (Out of Memory - OOM), thuật toán tự động đếm tổng số ảnh thực tế ($Total$) và tính toán chia nhỏ thành $n$ lô sao cho lượng ảnh nạp vào GPU không vượt quá giới hạn:
#
# $$\text{Total} / n \le \text{Max\_Batch\_Size}$$
#
# Sau khi hoàn tất mỗi lô ảnh, `Worker Inpainting` hoặc luồng thu hồi tài nguyên chủ động dọn dẹp bộ nhớ đồ họa bằng lệnh:
# ```python
# # Triển khai giải phóng bộ nhớ sau mỗi lô xử lý nhằm ngăn tràn VRAM (OOM)
# import torch  # type: ignore
# import gc
#
# def release_gpu_memory():
#     if torch.cuda.is_available():
#         torch.cuda.empty_cache()
#     gc.collect()
# ```
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #### 📥 Cơ chế Universal Model Downloader (Wrapper) cho MỌI mô hình AI:
# Để đảm bảo sự đồng nhất tuyệt đối, thay vì giả định người dùng đã cài đặt sẵn các mô hình AI (như OCR, Inpaint, Upscale), **tất cả** các lớp triển khai thực tế (Implementation Classes) đều được thiết kế dưới dạng **"Downloader Wrapper"**.
# - **Chủ động tải về (On-Demand Manual):** Khi Pipeline gọi `load_weights()` hoặc `load_model()`, người dùng sẽ chủ động bấm nút tải về (hệ thống kiểm tra xem tệp weights (.bin, .pth, .onnx) đã tồn tại trong thư mục `models/` tương ứng chưa.
# - **Tự động giải nén & Xác thực:** Khi người dùng yêu cầu, phần mềm sẽ tải về từ HuggingFace/Github Release, tiến hành giải nén và kiểm tra mã băm (SHA256) để chống lỗi file.
# - **Đồng nhất kiến trúc:** Bất kể là mô hình Dịch, Nhận diện chữ (OCR) hay Xóa nền (Inpaint), tất cả đều tuân thủ chung quy trình: `Kiểm tra tồn tại -> Báo cáo về UI (Đang tải...) -> Tải về -> Nạp vào VRAM`.

# %%
# Chẩn đoán: Kiểm tra các tệp cấu hình và mô hình dịch thuật cục bộ
import os

project_root = os.getcwd()
configs_dir = os.path.join(project_root, ".config", "models")
models_dir = os.path.join(project_root, "models", "Offline Translator")

print(f"[1] Quét các cấu hình trong thư mục: {configs_dir}\n")
if os.path.exists(configs_dir):
    files = sorted(os.listdir(configs_dir))
    for f in files:
        if f.endswith(('.yaml', '.yml')):
            path = os.path.join(configs_dir, f)
            size = os.path.getsize(path)
            print(f"  [✓] {f:<35} ({size} bytes)")
else:
    print(f"  [✗] Không tìm thấy thư mục cấu hình tại: {configs_dir}")

print(f"\n[2] Quét các mô hình cục bộ trong thư mục: {models_dir}\n")
if os.path.exists(models_dir):
    models = sorted(os.listdir(models_dir))
    for model in models:
        model_path = os.path.join(models_dir, model)
        if os.path.isdir(model_path):
            contents = os.listdir(model_path)
            has_bin = any(name.endswith(('.bin', '.safetensors', '.onnx')) for name in contents)
            print(f"  [✓] Mô hình: {model:<15} ({len(contents)} tệp, đã tải trọng số: {'CÓ' if has_bin else 'KHÔNG'})")
            for item in sorted(contents):
                if item.endswith(('.bin', '.safetensors', '.json', '.model')):
                    size_mb = os.path.getsize(os.path.join(model_path, item)) / (1024 * 1024)
                    print(f"      - {item:<35} ({size_mb:.2f} MB)")
else:
    print(f"  [✗] Không tìm thấy thư mục mô hình cục bộ tại: {models_dir}")
# Out:
# [1] Quét các cấu hình trong thư mục: /home/bimatkeo/Documents/Translator/Bimatkeo_Translator/.config/models
#
#   [✓] local_versions.yaml                 (38 bytes)
#   [✓] model_ai_translator.yaml            (741 bytes)
#   [✓] model_colorizer.yaml                (82 bytes)
#   [✓] model_detector.yaml                 (368 bytes)
#   [✓] model_inpainter.yaml                (294 bytes)
#   [✓] model_ocr.yaml                      (264 bytes)
#   [✓] model_offline_translator.yaml       (835 bytes)
#   [✓] model_registry.yaml                 (6333 bytes)
#   [✓] model_upscaler.yaml                 (205 bytes)
#
# [2] Quét các mô hình cục bộ trong thư mục: /home/bimatkeo/Documents/Translator/Bimatkeo_Translator/models/Offline Translator
#
#   [✓] Mô hình: M2M100          (3 tệp, đã tải trọng số: CÓ)
#       - model.bin                           (467.94 MB)
#       - sentencepiece.model                 (2.31 MB)
#   [✓] Mô hình: MBart50         (4 tệp, đã tải trọng số: CÓ)
#       - config.json                         (0.00 MB)
#       - generation_config.json              (0.00 MB)
#       - model.safetensors                   (2331.33 MB)
#       - pytorch_model.bin                   (1485.00 MB)
#   [✓] Mô hình: NLLB            (7 tệp, đã tải trọng số: CÓ)
#       - config.json                         (0.00 MB)
#       - generation_config.json              (0.00 MB)
#       - pytorch_model.bin                   (2346.48 MB)
#       - sentencepiece.bpe.model             (4.63 MB)
#       - special_tokens_map.json             (0.00 MB)
#       - tokenizer.json                      (16.53 MB)
#       - tokenizer_config.json               (0.00 MB)

# %%
# Chẩn đoán: Kiểm tra môi trường chạy Python và tính sẵn sàng của CUDA/GPU
import sys

print(f"Phiên bản Python: {sys.version}")
print(f"Trình thực thi Python: {sys.executable}")
print("-" * 70)

import importlib.util
torch_installed = importlib.util.find_spec("torch") is not None

if torch_installed:
    import torch  # type: ignore
    print(f"Đã cài đặt PyTorch (torch): Có (v{torch.__version__})")
    print(f"Hỗ trợ tăng tốc CUDA (NVIDIA GPU): {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"  - Thiết bị: {torch.cuda.get_device_name(0)}")
        print(f"  - Tổng dung lượng VRAM: {torch.cuda.get_device_properties(0).total_memory / (1024**3):.2f} GB")
    else:
        print("  - Đang chạy ở chế độ dự phòng CPU (không kích hoạt tăng tốc GPU)")
else:
    print("Đã cài đặt PyTorch (torch): Không (hoặc không tìm thấy trong môi trường Python hiện tại)")
    print("Hỗ trợ tăng tốc CUDA (NVIDIA GPU): Không khả dụng (yêu cầu cài đặt PyTorch)")
# Out:
# Phiên bản Python: 3.14.6 (main, Jun 11 2026, 04:03:53) [Clang 22.1.3 ]
# Trình thực thi Python: /home/bimatkeo/Documents/Translator/Bimatkeo_Translator/.venv/bin/python
# ----------------------------------------------------------------------
# Đã cài đặt PyTorch (torch): Có (v2.12.1+cu130)
# Hỗ trợ tăng tốc CUDA (NVIDIA GPU): True
#   - Thiết bị: NVIDIA GeForce RTX 3050 6GB Laptop GPU
#   - Tổng dung lượng VRAM: 5.67 GB
